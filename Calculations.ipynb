# %%
import xml.dom.minidom
import glob
import matplotlib.pyplot as plt

# %%
def main():
    files = glob.glob("/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/*.xml")
    print (files)
    '''
    doc = xml.dom.minidom.parse("/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmon.xml")

    print (doc.nodeName)
    print (doc.firstChild.tagName)
    '''

# %%
main()
# Out:
# ['/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/flowmon-20.xml', '/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/flowmon-5.xml', '/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/flowmon-15.xml', '/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/flowmon-10.xml']

# %%
''' Matrices '''
connections = [5, 10, 15, 20]
pdf = [74.5022, 84.9826, 71.70, 69.59]
RXbitrate = [1854.21, 3466.81, 4817.79,  6255.12]

# %%
plt.plot(connections, pdf)
plt.ylabel('PDF')
plt.xlabel('Connections')
plt.xticks([5, 10, 15, 20])
# Out:
# ([<matplotlib.axis.XTick at 0x7f4919b83d68>,
#   <matplotlib.axis.XTick at 0x7f4919b83630>,
#   <matplotlib.axis.XTick at 0x7f4919b83080>,
#   <matplotlib.axis.XTick at 0x7f4919901128>],
#  <a list of 4 Text xticklabel objects>)

# %%
plt.plot(connections, RXbitrate)
plt.ylabel('RXbitrate')
plt.xlabel('Connections')
plt.xticks([5, 10, 15, 20])
# Out:
# ([<matplotlib.axis.XTick at 0x7f49198e4ef0>,
#   <matplotlib.axis.XTick at 0x7f49198e47f0>,
#   <matplotlib.axis.XTick at 0x7f49198e4278>,
#   <matplotlib.axis.XTick at 0x7f4919884eb8>],
#  <a list of 4 Text xticklabel objects>)
