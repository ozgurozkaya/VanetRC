# %%
import xml.dom.minidom
import glob
import matplotlib.pyplot as plt

# %%
def main():
    '''
    files = glob.glob("/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmonitor/*.xml")
    print (files)
    '''
    '''
    doc = xml.dom.minidom.parse("/home/ozgur/workspace/ns-allinone-3.30.1/ns-3.30.1/xml/flowmon.xml")

    print (doc.nodeName)
    print (doc.firstChild.tagName)
    '''

# %%
main()

# %%
''' Matrices '''
connections = [5, 10, 15, 20]
pdfOurs = [90.28, 97.18, 98.54, 98.11]
RXbitrateOurs = [756.09, 1374.43, 1967.31, 2699.27]

pdfTheirs = [98.41, 98.23, 99.26, 89.54]
RXbitrateTheirs = [737.34, 1473.81, 2203.75,  2671.18]

# %%
plt.plot(connections, pdfOurs, marker='o', markerfacecolor='blue', label="Bizinkisi")
plt.plot(connections, pdfTheirs, marker='x', markerfacecolor='red', label="Onlarınkisi")
plt.legend(loc='lower left')
plt.ylabel('Packet Delivery Fraction (%)')
plt.xlabel('Connections')
plt.xticks([5, 10, 15, 20])
# Out:
# ([<matplotlib.axis.XTick at 0x7fe9dc21b750>,
#   <matplotlib.axis.XTick at 0x7fe9dc21bfd0>,
#   <matplotlib.axis.XTick at 0x7fe9dc4873d0>,
#   <matplotlib.axis.XTick at 0x7fe9ec40f450>],
#  <a list of 4 Text xticklabel objects>)

# %%
plt.plot(connections, RXbitrateOurs, marker='o', markerfacecolor='blue', label="Bizinkisi")
plt.plot(connections, RXbitrateTheirs, marker='x', markerfacecolor='red', label="Onlarınkisi")
plt.legend(loc='upper left')
plt.ylabel('RXbitrate (kbps)')
plt.xlabel('Connections')
plt.xticks([5, 10, 15, 20])
# Out:
# ([<matplotlib.axis.XTick at 0x7fe9c482f8d0>,
#   <matplotlib.axis.XTick at 0x7fe9c4889b90>,
#   <matplotlib.axis.XTick at 0x7fe9c4881a50>,
#   <matplotlib.axis.XTick at 0x7fe9c47dea50>],
#  <a list of 4 Text xticklabel objects>)
